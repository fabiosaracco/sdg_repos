# %% [markdown]
# ### CODE SAMPLE ###

# %%
! pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 1.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
! pip install pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer
from pypdf import PdfReader

# %% [markdown]
# **The models can be found on https://www.sbert.net/ and on the original hugginface**

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Error while downloading from https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/vocab.txt: HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out.
# Trying to resume download...
# WARNING:huggingface_hub.file_download:Error while downloading from https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/vocab.txt: HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out.
# Trying to resume download...
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Error while downloading from https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/vocab.txt: HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out.
# Trying to resume download...
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sentences = [
    "This framework generates embeddings for each input sentence",
    "Sentences are passed as a list of string.",
    "The quick brown fox jumps over the lazy dog.",
]
sentence_embeddings = model.encode(sentences)

# %% [markdown]
# **Vectors should be reshaped with -1, 1 to get something like (384,1)**

# %%
sentence_embeddings[0].reshape(-1,1).shape

# %%
simlarity = cosine_similarity(sentence_embeddings[0].reshape(1,-1),sentence_embeddings[1].reshape(1,-1))[0][0]

# %%
simlarity2 = cosine_similarity(sentence_embeddings[0].reshape(1,-1),sentence_embeddings[2].reshape(1,-1))[0][0]

# %%
print(sentences[0], "::::", sentences[1], "SIM_LEVEL" , simlarity)

# %%
print(sentences[0], "::::", sentences[2], "SIM_LEVEL" , simlarity2)
